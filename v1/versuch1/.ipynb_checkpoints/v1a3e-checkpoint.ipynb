# %% [markdown]
# # 3e)

# %% [markdown]
# k=5, S=1

# %%
# Programmgeruest zu Versuch 1, Aufgabe 3e
import numpy as np
import matplotlib.pyplot as plt
from time import process_time
from v1a2 import *

# (i) define parameters K,S,N and 2-dimensional Gaussian
C=2;
K=5;
S=1;
N_list=[10, 20,50,100,200,500,1000,2000,5000,10000];                      # REPLACE! Insert list of data set size N as desired
mu1, mu2 = [1,1], [3,1]               # expectations for the two classes
cov1 = [[1,0.5],\
        [0.5,1]]                      # covariance matrix for class 1
cov2 = [[1,0.5],\
        [0.5,1]]                      # covariance matrix for class 2
time_comp_naive  = np.zeros(len(N_list));    # allocate memory for time measurements for naive KNN
time_comp_kdtree = np.zeros(len(N_list));    # allocate memory for time measurements for KNN with KD tree

# (ii) Make (wall-)time measurements for cross validations of data sets of various sizes N
for i in range(len(N_list)):
    N=N_list[i]
    print("\nrunning KNN cross validation for K=",K,"S=",S,"N=",N)

    # (ii.a) generate synthetic data 
    N1,N2=N//2,N//2                   # N1 and N2 data vectors for the two classes  
    X1 = np.random.multivariate_normal(mu1,cov1,(N1))    # Gaussian data vectors for class 1
    X2 = np.random.multivariate_normal(mu2,cov2,(N2))    # Gaussian data vectors for class 2
    T1,T2 = N1*[0],N2*[1]             # corresponding class labels 
    X = np.concatenate((X1,X2))       # entire data set
    T = np.concatenate((T1,T2))       # entire label set

    # (ii.b) do cross validation for this data set using naive KNN
    knnc = KNNClassifier(C,K)         # create classifier object of class KNNClassifier
    t1=process_time()                        # start time
    pE,pCE = knnc.crossvalidate(S,X,T)# do S-fold cross validation for data X,T
    t2=process_time()                        # end time
    time_comp_naive[i]=t2-t1          # computing time in seconds
    print("\nS=",S," fold cross validation using the naive KNNClassifier yields the following results:")
    print("Classification error probability = ", pE)
    print("Accuracy = ", 1.0-pE)
    print("Confusion Error Probabilities p(class i|class j) = \n", pCE)
    print("Computing time = ", time_comp_naive[i], " sec")

    # (ii.c) do cross validation for this data set using KNN with KD trees
    fknnc=FastKNNClassifier(C,K)
    ft1=process_time()
    pE_fknnc,pCE_fknnc=fknnc.crossvalidate(S,X,T)
    ft2=process_time()
    time_comp_kdtree[i]=ft2-ft1          
    print("\nS=",S," fold cross validation using the KD-Tree-KNNClassifier yields the following results:")
    print("Classification error probability = ", pE_fknnc)
    print("Accuracy = ", 1.0-pE_fknnc)
    print("Confusion Error Probabilities p(class i|class j) = \n", pCE_fknnc)
    print("Computing time = ", time_comp_kdtree[i], " sec")

# (iii) print results
print("\nResults for N=",N_list,"\ntime_comp_naive=",time_comp_naive,"\ntime_comp_kdtree=",time_comp_kdtree)

# (iv) plot results
f=plt.figure()
a = f.add_subplot(111)
a.plot(N_list,time_comp_naive,'bo-',N_list,time_comp_kdtree,'gd-')       # plot computing times 
a.set_xlabel('number of data vectors N');
a.set_ylabel('computing time [sec]');
a.set_title('Computing time for '+str(S)+'-fold cross validation for KNN with K='+str(K));
a.grid()

plt.show()
# Out:
# running KNN cross validation for K= 5 S= 1 N= 10
#
# S= 1  fold cross validation using the naive KNNClassifier yields the following results:
# Classification error probability =  0.4
# Accuracy =  0.6
# Confusion Error Probabilities p(class i|class j) =
#  [[1.  0.8]
#  [0.  0.2]]
# Computing time =  0.0  sec
#
# S= 1  fold cross validation using the KD-Tree-KNNClassifier yields the following results:
# Classification error probability =  0.4
# Accuracy =  0.6
# Confusion Error Probabilities p(class i|class j) =
#  [[1.  0.8]
#  [0.  0.2]]
# Computing time =  0.0  sec
#
# running KNN cross validation for K= 5 S= 1 N= 20
#
# S= 1  fold cross validation using the naive KNNClassifier yields the following results:
# Classification error probability =  0.1
# Accuracy =  0.9
# Confusion Error Probabilities p(class i|class j) =
#  [[0.9 0.1]
#  [0.1 0.9]]
# Computing time =  0.0  sec
#
# S= 1  fold cross validation using the KD-Tree-KNNClassifier yields the following results:
# Classification error probability =  0.1
# Accuracy =  0.9
# Confusion Error Probabilities p(class i|class j) =
#  [[0.9 0.1]
#  [0.1 0.9]]
# Computing time =  0.0  sec
#
# running KNN cross validation for K= 5 S= 1 N= 50
#
# S= 1  fold cross validation using the naive KNNClassifier yields the following results:
# Classification error probability =  0.14
# Accuracy =  0.86
# Confusion Error Probabilities p(class i|class j) =
#  [[0.84 0.12]
#  [0.16 0.88]]
# Computing time =  0.015625  sec
#
# S= 1  fold cross validation using the KD-Tree-KNNClassifier yields the following results:
# Classification error probability =  0.14
# Accuracy =  0.86
# Confusion Error Probabilities p(class i|class j) =
#  [[0.84 0.12]
#  [0.16 0.88]]
# Computing time =  0.0  sec
#
# running KNN cross validation for K= 5 S= 1 N= 100
#
# S= 1  fold cross validation using the naive KNNClassifier yields the following results:
# Classification error probability =  0.13
# Accuracy =  0.87
# Confusion Error Probabilities p(class i|class j) =
#  [[0.9  0.16]
#  [0.1  0.84]]
# Computing time =  0.078125  sec
#
# S= 1  fold cross validation using the KD-Tree-KNNClassifier yields the following results:
# Classification error probability =  0.13
# Accuracy =  0.87
# Confusion Error Probabilities p(class i|class j) =
#  [[0.9  0.16]
#  [0.1  0.84]]
# Computing time =  0.0  sec
#
# running KNN cross validation for K= 5 S= 1 N= 200
#
# S= 1  fold cross validation using the naive KNNClassifier yields the following results:
# Classification error probability =  0.1
# Accuracy =  0.9
# Confusion Error Probabilities p(class i|class j) =
#  [[0.93 0.13]
#  [0.07 0.87]]
# Computing time =  0.265625  sec
#
# S= 1  fold cross validation using the KD-Tree-KNNClassifier yields the following results:
# Classification error probability =  0.1
# Accuracy =  0.9
# Confusion Error Probabilities p(class i|class j) =
#  [[0.93 0.13]
#  [0.07 0.87]]
# Computing time =  0.015625  sec
#
# running KNN cross validation for K= 5 S= 1 N= 500
#
# S= 1  fold cross validation using the naive KNNClassifier yields the following results:
# Classification error probability =  0.098
# Accuracy =  0.902
# Confusion Error Probabilities p(class i|class j) =
#  [[0.888 0.084]
#  [0.112 0.916]]
# Computing time =  1.65625  sec
#
# S= 1  fold cross validation using the KD-Tree-KNNClassifier yields the following results:
# Classification error probability =  0.098
# Accuracy =  0.902
# Confusion Error Probabilities p(class i|class j) =
#  [[0.888 0.084]
#  [0.112 0.916]]
# Computing time =  0.015625  sec
#
# running KNN cross validation for K= 5 S= 1 N= 1000
#
# S= 1  fold cross validation using the naive KNNClassifier yields the following results:
# Classification error probability =  0.099
# Accuracy =  0.901
# Confusion Error Probabilities p(class i|class j) =
#  [[0.896 0.094]
#  [0.104 0.906]]
# Computing time =  2.125  sec
#
# S= 1  fold cross validation using the KD-Tree-KNNClassifier yields the following results:
# Classification error probability =  0.099
# Accuracy =  0.901
# Confusion Error Probabilities p(class i|class j) =
#  [[0.896 0.094]
#  [0.104 0.906]]
# Computing time =  0.03125  sec
#
# running KNN cross validation for K= 5 S= 1 N= 2000
#
# S= 1  fold cross validation using the naive KNNClassifier yields the following results:
# Classification error probability =  0.1075
# Accuracy =  0.8925
# Confusion Error Probabilities p(class i|class j) =
#  [[0.894 0.109]
#  [0.106 0.891]]
# Computing time =  11.3125  sec
#
# S= 1  fold cross validation using the KD-Tree-KNNClassifier yields the following results:
# Classification error probability =  0.1075
# Accuracy =  0.8925
# Confusion Error Probabilities p(class i|class j) =
#  [[0.894 0.109]
#  [0.106 0.891]]
# Computing time =  0.046875  sec
#
# running KNN cross validation for K= 5 S= 1 N= 5000
#
# S= 1  fold cross validation using the naive KNNClassifier yields the following results:
# Classification error probability =  0.104
# Accuracy =  0.896
# Confusion Error Probabilities p(class i|class j) =
#  [[0.892 0.1  ]
#  [0.108 0.9  ]]
# Computing time =  59.078125  sec
#
# S= 1  fold cross validation using the KD-Tree-KNNClassifier yields the following results:
# Classification error probability =  0.104
# Accuracy =  0.896
# Confusion Error Probabilities p(class i|class j) =
#  [[0.892 0.1  ]
#  [0.108 0.9  ]]
# Computing time =  0.125  sec
#
# running KNN cross validation for K= 5 S= 1 N= 10000
#
# S= 1  fold cross validation using the naive KNNClassifier yields the following results:
# Classification error probability =  0.1041
# Accuracy =  0.8959
# Confusion Error Probabilities p(class i|class j) =
#  [[0.893  0.1012]
#  [0.107  0.8988]]
# Computing time =  352.6875  sec
#
# S= 1  fold cross validation using the KD-Tree-KNNClassifier yields the following results:
# Classification error probability =  0.1041
# Accuracy =  0.8959
# Confusion Error Probabilities p(class i|class j) =
#  [[0.893  0.1012]
#  [0.107  0.8988]]
# Computing time =  0.25  sec
#
# Results for N= [10, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000]
# time_comp_naive= [0.0000000e+00 0.0000000e+00 1.5625000e-02 7.8125000e-02 2.6562500e-01
#  1.6562500e+00 2.1250000e+00 1.1312500e+01 5.9078125e+01 3.5268750e+02]
# time_comp_kdtree= [0.       0.       0.       0.       0.015625 0.015625 0.03125  0.046875
#  0.125    0.25    ]

# %% [markdown]
# k=5, S=5

# %%
# (i) define parameters K,S,N and 2-dimensional Gaussian
C=2;
K=5;
S=5;
N_list=[10, 20,50,100,200,500,1000,2000,5000,10000];                      # REPLACE! Insert list of data set size N as desired
mu1, mu2 = [1,1], [3,1]               # expectations for the two classes
cov1 = [[1,0.5],\
        [0.5,1]]                      # covariance matrix for class 1
cov2 = [[1,0.5],\
        [0.5,1]]                      # covariance matrix for class 2
time_comp_naive  = np.zeros(len(N_list));    # allocate memory for time measurements for naive KNN
time_comp_kdtree = np.zeros(len(N_list));    # allocate memory for time measurements for KNN with KD tree

# (ii) Make (wall-)time measurements for cross validations of data sets of various sizes N
for i in range(len(N_list)):
    N=N_list[i]
    print("\nrunning KNN cross validation for K=",K,"S=",S,"N=",N)

    # (ii.a) generate synthetic data 
    N1,N2=N//2,N//2                   # N1 and N2 data vectors for the two classes  
    X1 = np.random.multivariate_normal(mu1,cov1,(N1))    # Gaussian data vectors for class 1
    X2 = np.random.multivariate_normal(mu2,cov2,(N2))    # Gaussian data vectors for class 2
    T1,T2 = N1*[0],N2*[1]             # corresponding class labels 
    X = np.concatenate((X1,X2))       # entire data set
    T = np.concatenate((T1,T2))       # entire label set

    # (ii.b) do cross validation for this data set using naive KNN
    knnc = KNNClassifier(C,K)         # create classifier object of class KNNClassifier
    t1=process_time()                        # start time
    pE,pCE = knnc.crossvalidate(S,X,T)# do S-fold cross validation for data X,T
    t2=process_time()                        # end time
    time_comp_naive[i]=t2-t1          # computing time in seconds
    print("\nS=",S," fold cross validation using the naive KNNClassifier yields the following results:")
    print("Classification error probability = ", pE)
    print("Accuracy = ", 1.0-pE)
    print("Confusion Error Probabilities p(class i|class j) = \n", pCE)
    print("Computing time = ", time_comp_naive[i], " sec")

    # (ii.c) do cross validation for this data set using KNN with KD trees
    fknnc=FastKNNClassifier(C,K)
    ft1=process_time()
    pE_fknnc,pCE_fknnc=fknnc.crossvalidate(S,X,T)
    ft2=process_time()
    time_comp_kdtree[i]=ft2-ft1          
    print("\nS=",S," fold cross validation using the KD-Tree-KNNClassifier yields the following results:")
    print("Classification error probability = ", pE_fknnc)
    print("Accuracy = ", 1.0-pE_fknnc)
    print("Confusion Error Probabilities p(class i|class j) = \n", pCE_fknnc)
    print("Computing time = ", time_comp_kdtree[i], " sec")

# (iii) print results
print("\nResults for N=",N_list,"\ntime_comp_naive=",time_comp_naive,"\ntime_comp_kdtree=",time_comp_kdtree)

# (iv) plot results
f=plt.figure()
a = f.add_subplot(111)
a.plot(N_list,time_comp_naive,'bo-',N_list,time_comp_kdtree,'gd-')       # plot computing times 
a.set_xlabel('number of data vectors N');
a.set_ylabel('computing time [sec]');
a.set_title('Computing time for '+str(S)+'-fold cross validation for KNN with K='+str(K));
a.grid()

plt.show()
# Out:
# running KNN cross validation for K= 5 S= 5 N= 10
#
# S= 5  fold cross validation using the naive KNNClassifier yields the following results:
# Classification error probability =  0.2
# Accuracy =  0.8
# Confusion Error Probabilities p(class i|class j) =
#  [[1.  0.4]
#  [0.  0.6]]
# Computing time =  0.0  sec
#
# S= 5  fold cross validation using the KD-Tree-KNNClassifier yields the following results:
# Classification error probability =  0.2
# Accuracy =  0.8
# Confusion Error Probabilities p(class i|class j) =
#  [[1.  0.4]
#  [0.  0.6]]
# Computing time =  0.0  sec
#
# running KNN cross validation for K= 5 S= 5 N= 20
#
# S= 5  fold cross validation using the naive KNNClassifier yields the following results:
# Classification error probability =  0.35
# Accuracy =  0.65
# Confusion Error Probabilities p(class i|class j) =
#  [[0.6 0.3]
#  [0.4 0.7]]
# Computing time =  0.015625  sec
#
# S= 5  fold cross validation using the KD-Tree-KNNClassifier yields the following results:
# Classification error probability =  0.3
# Accuracy =  0.7
# Confusion Error Probabilities p(class i|class j) =
#  [[0.7 0.3]
#  [0.3 0.7]]
# Computing time =  0.0  sec
#
# running KNN cross validation for K= 5 S= 5 N= 50
#
# S= 5  fold cross validation using the naive KNNClassifier yields the following results:
# Classification error probability =  0.12
# Accuracy =  0.88
# Confusion Error Probabilities p(class i|class j) =
#  [[0.8  0.04]
#  [0.2  0.96]]
# Computing time =  0.0  sec
#
# S= 5  fold cross validation using the KD-Tree-KNNClassifier yields the following results:
# Classification error probability =  0.1
# Accuracy =  0.9
# Confusion Error Probabilities p(class i|class j) =
#  [[0.8 0. ]
#  [0.2 1. ]]
# Computing time =  0.0  sec
#
# running KNN cross validation for K= 5 S= 5 N= 100
#
# S= 5  fold cross validation using the naive KNNClassifier yields the following results:
# Classification error probability =  0.19
# Accuracy =  0.81
# Confusion Error Probabilities p(class i|class j) =
#  [[0.8  0.18]
#  [0.2  0.82]]
# Computing time =  0.015625  sec
#
# S= 5  fold cross validation using the KD-Tree-KNNClassifier yields the following results:
# Classification error probability =  0.19
# Accuracy =  0.81
# Confusion Error Probabilities p(class i|class j) =
#  [[0.78 0.16]
#  [0.22 0.84]]
# Computing time =  0.0  sec
#
# running KNN cross validation for K= 5 S= 5 N= 200
#
# S= 5  fold cross validation using the naive KNNClassifier yields the following results:
# Classification error probability =  0.13
# Accuracy =  0.87
# Confusion Error Probabilities p(class i|class j) =
#  [[0.87 0.13]
#  [0.13 0.87]]
# Computing time =  0.078125  sec
#
# S= 5  fold cross validation using the KD-Tree-KNNClassifier yields the following results:
# Classification error probability =  0.14
# Accuracy =  0.86
# Confusion Error Probabilities p(class i|class j) =
#  [[0.86 0.14]
#  [0.14 0.86]]
# Computing time =  0.0  sec
#
# running KNN cross validation for K= 5 S= 5 N= 500
#
# S= 5  fold cross validation using the naive KNNClassifier yields the following results:
# Classification error probability =  0.114
# Accuracy =  0.886
# Confusion Error Probabilities p(class i|class j) =
#  [[0.9   0.128]
#  [0.1   0.872]]
# Computing time =  0.4375  sec
#
# S= 5  fold cross validation using the KD-Tree-KNNClassifier yields the following results:
# Classification error probability =  0.114
# Accuracy =  0.886
# Confusion Error Probabilities p(class i|class j) =
#  [[0.9   0.128]
#  [0.1   0.872]]
# Computing time =  0.015625  sec
#
# running KNN cross validation for K= 5 S= 5 N= 1000
#
# S= 5  fold cross validation using the naive KNNClassifier yields the following results:
# Classification error probability =  0.151
# Accuracy =  0.849
# Confusion Error Probabilities p(class i|class j) =
#  [[0.852 0.154]
#  [0.148 0.846]]
# Computing time =  4.375  sec
#
# S= 5  fold cross validation using the KD-Tree-KNNClassifier yields the following results:
# Classification error probability =  0.149
# Accuracy =  0.851
# Confusion Error Probabilities p(class i|class j) =
#  [[0.856 0.154]
#  [0.144 0.846]]
# Computing time =  0.109375  sec
#
# running KNN cross validation for K= 5 S= 5 N= 2000
#
# S= 5  fold cross validation using the naive KNNClassifier yields the following results:
# Classification error probability =  0.1275
# Accuracy =  0.8725
# Confusion Error Probabilities p(class i|class j) =
#  [[0.874 0.129]
#  [0.126 0.871]]
# Computing time =  18.171875  sec
#
# S= 5  fold cross validation using the KD-Tree-KNNClassifier yields the following results:
# Classification error probability =  0.1285
# Accuracy =  0.8714999999999999
# Confusion Error Probabilities p(class i|class j) =
#  [[0.879 0.136]
#  [0.121 0.864]]
# Computing time =  0.046875  sec
#
# running KNN cross validation for K= 5 S= 5 N= 5000
#
# S= 5  fold cross validation using the naive KNNClassifier yields the following results:
# Classification error probability =  0.147
# Accuracy =  0.853
# Confusion Error Probabilities p(class i|class j) =
#  [[0.8536 0.1476]
#  [0.1464 0.8524]]
# Computing time =  95.609375  sec
#
# S= 5  fold cross validation using the KD-Tree-KNNClassifier yields the following results:
# Classification error probability =  0.1428
# Accuracy =  0.8572
# Confusion Error Probabilities p(class i|class j) =
#  [[0.8604 0.146 ]
#  [0.1396 0.854 ]]
# Computing time =  0.125  sec
#
# running KNN cross validation for K= 5 S= 5 N= 10000
#
# S= 5  fold cross validation using the naive KNNClassifier yields the following results:
# Classification error probability =  0.1369
# Accuracy =  0.8631
# Confusion Error Probabilities p(class i|class j) =
#  [[0.8618 0.1356]
#  [0.1382 0.8644]]
# Computing time =  327.375  sec
#
# S= 5  fold cross validation using the KD-Tree-KNNClassifier yields the following results:
# Classification error probability =  0.1398
# Accuracy =  0.8602
# Confusion Error Probabilities p(class i|class j) =
#  [[0.8584 0.138 ]
#  [0.1416 0.862 ]]
# Computing time =  0.375  sec
#
# Results for N= [10, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000]
# time_comp_naive= [0.0000000e+00 1.5625000e-02 0.0000000e+00 1.5625000e-02 7.8125000e-02
#  4.3750000e-01 4.3750000e+00 1.8171875e+01 9.5609375e+01 3.2737500e+02]
# time_comp_kdtree= [0.       0.       0.       0.       0.       0.015625 0.109375 0.046875
#  0.125    0.375   ]
